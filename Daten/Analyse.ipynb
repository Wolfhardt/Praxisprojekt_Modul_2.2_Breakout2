# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from matplotlib.pyplot import figure
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.image as mpimg

# %%
ausland_tages = pd.read_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_Ausland_Tage.csv",  \
                            usecols=["Datum", "Umsatz_C_Ausland", "Umsatz_A_Ausland", "Umsatz_B_Ausland", "Umsatz_gesamt_Ausland"],\
                            parse_dates=['Datum']    )
ausland_tages
# Out:
#          Datum  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 0   2021-01-01         517.78383         17.132115         50.000005
# 1   2021-02-01         210.76096         57.353725         97.000000
# 2   2021-03-01         438.47352        114.746857         60.000000
# 3   2021-04-01         263.19869        113.251181         95.000000
# 4   2021-05-01         535.95553          4.186462          4.000000
# ..         ...               ...               ...               ...
# 360 2021-12-27         858.86110         48.681712         15.000000
# 361 2021-12-28         105.59890         54.774542         64.000000
# 362 2021-12-29         340.43550        151.450508         43.000000
# 363 2021-12-30         726.17010         39.406492         99.000000
# 364 2021-12-31         132.40700        111.467425         66.000000
#
#      Umsatz_gesamt_Ausland
# 0               584.915950
# 1               365.114685
# 2               613.220377
# ...

# %%
ausland_tages.dtypes
# Out:
# Datum                    datetime64[ns]
# Umsatz_C_Ausland                float64
# Umsatz_A_Ausland                float64
# Umsatz_B_Ausland                float64
# Umsatz_gesamt_Ausland           float64
# dtype: object

# %%
#ausland_tages.set_index('Datum', inplace=True)

# %%
ausland_tages['Datum'] = pd.to_datetime(ausland_tages['Datum'])
ausland_tages['Wochentag'] = ausland_tages['Datum'].dt.strftime('%A')
ausland_tages['Kalenderwoche'] = ausland_tages['Datum'].dt.strftime('%W')
ausland_tages['Monat'] = ausland_tages['Datum'].dt.strftime('%B')
ausland_tages
# Out:
#          Datum  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 0   2021-01-01         517.78383         17.132115         50.000005
# 1   2021-02-01         210.76096         57.353725         97.000000
# 2   2021-03-01         438.47352        114.746857         60.000000
# 3   2021-04-01         263.19869        113.251181         95.000000
# 4   2021-05-01         535.95553          4.186462          4.000000
# ..         ...               ...               ...               ...
# 360 2021-12-27         858.86110         48.681712         15.000000
# 361 2021-12-28         105.59890         54.774542         64.000000
# 362 2021-12-29         340.43550        151.450508         43.000000
# 363 2021-12-30         726.17010         39.406492         99.000000
# 364 2021-12-31         132.40700        111.467425         66.000000
#
#      Umsatz_gesamt_Ausland  Wochentag Kalenderwoche     Monat
# 0               584.915950     Friday            00   January
# ...

# %%
colors = sns.color_palette('pastel')
ausland_tages.groupby(['Wochentag']).sum () \
                                        .plot(kind='pie', \
                                            y='Umsatz_C_Ausland', \
                                            autopct='%1.0f%%', \
                                            legend=False,colors = colors, \
                                            title='Umsatz Produkt C nach Wochentagen')
plt.ylabel("")
#plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_C_Tage")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14280\2324060404.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ausland_tages.groupby(['Wochentag']).sum () \
# Text(0, 0.5, '')

# %%
colors = sns.color_palette('pastel')
ausland_tages.groupby(['Wochentag']).sum () \
                                        .plot(kind='pie', \
                                            y='Umsatz_B_Ausland', \
                                            autopct='%1.0f%%', \
                                            legend=False,colors = colors, \
                                            title='Umsatz Produkt B nach Wochentagen')
plt.ylabel("")
plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_B_Tage")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14280\2453470070.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ausland_tages.groupby(['Wochentag']).sum () \

# %%
colors = sns.color_palette('pastel')
ausland_tages.groupby(['Wochentag']).sum () \
                                        .plot(kind='pie', \
                                            y='Umsatz_A_Ausland', \
                                            autopct='%1.0f%%', \
                                            legend=False,colors = colors, \
                                            title='Umsatz Produkt A nach Wochentagen')
plt.ylabel("")
plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_A_Tage")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14280\3262299773.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ausland_tages.groupby(['Wochentag']).sum () \

# %%
colors = sns.color_palette('pastel')
ausland_tages.groupby(['Monat']).sum () \
                                        .plot(kind='pie', \
                                            y='Umsatz_gesamt_Ausland', \
                                            autopct='%1.0f%%', \
                                            legend=False,colors = colors, \
                                            title='Gesamtumsatz nach Monaten')
plt.ylabel("")
#plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_Aus_gesamt_Monat")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14280\2091953146.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ausland_tages.groupby(['Monat']).sum () \
# Text(0, 0.5, '')

# %%
ausland_tages.describe()
# Out:
#        Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# count        365.000000        365.000000        365.000000
# mean         496.254743         53.052614         50.394521
# std          282.785513         39.525230         29.375140
# min            1.025900          0.269320          0.000000
# 25%          235.650810         20.319721         26.000000
# 50%          517.783830         47.325915         50.000005
# 75%          733.315880         78.839589         77.000000
# max          993.935700        171.461856        100.000000
#
#        Umsatz_gesamt_Ausland
# count             365.000000
# mean              599.701877
# std               287.766058
# min                53.944434
# 25%               349.054438
# 50%               619.504486
# 75%               838.471316
# max              1149.038282

# %%
x = ausland_tages[ausland_tages["Umsatz_gesamt_Ausland"]== ausland_tages["Umsatz_gesamt_Ausland"].min()]
print(x)
# Out:
#          Datum  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 113 2021-04-24           19.5827         22.361734              12.0
#
#      Umsatz_gesamt_Ausland Wochentag Kalenderwoche  Monat
# 113              53.944434  Saturday            16  April

# %%
y = ausland_tages[ausland_tages["Umsatz_gesamt_Ausland"]== ausland_tages["Umsatz_gesamt_Ausland"].max()]
print(y)
# Out:
#          Datum  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 289 2021-10-17          993.9357        148.102582               7.0
#
#      Umsatz_gesamt_Ausland Wochentag Kalenderwoche    Monat
# 289            1149.038282    Sunday            41  October

# %%
r = ausland_tages[ausland_tages["Umsatz_A_Ausland"]== ausland_tages["Umsatz_A_Ausland"].max()]
print(r)
# Out:
#          Datum  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 126 2021-07-05         480.90637        171.461856              56.0
#
#      Umsatz_gesamt_Ausland Wochentag Kalenderwoche Monat
# 126             708.368226    Monday            27  July

# %%
ausland_tages.columns
# Out:
# Index(['Datum', 'Umsatz_C_Ausland', 'Umsatz_A_Ausland', 'Umsatz_B_Ausland',
#        'Umsatz_gesamt_Ausland', 'Wochentag', 'Kalenderwoche', 'Monat'],
#       dtype='object')

# %%
neue_reihenfolge = ['Datum','Wochentag' , 'Monat', 'Kalenderwoche',  'Umsatz_A_Ausland', 'Umsatz_B_Ausland','Umsatz_C_Ausland',
       'Umsatz_gesamt_Ausland']
ausland_tages = ausland_tages[neue_reihenfolge]
ausland_tages
# Out:
#          Datum  Wochentag     Monat Kalenderwoche  Umsatz_A_Ausland  \
# 0   2021-01-01     Friday   January            00         17.132115
# 1   2021-02-01     Monday  February            05         57.353725
# 2   2021-03-01     Monday     March            09        114.746857
# 3   2021-04-01   Thursday     April            13        113.251181
# 4   2021-05-01   Saturday       May            17          4.186462
# ..         ...        ...       ...           ...               ...
# 360 2021-12-27     Monday  December            52         48.681712
# 361 2021-12-28    Tuesday  December            52         54.774542
# 362 2021-12-29  Wednesday  December            52        151.450508
# 363 2021-12-30   Thursday  December            52         39.406492
# 364 2021-12-31     Friday  December            52        111.467425
#
#      Umsatz_B_Ausland  Umsatz_C_Ausland  Umsatz_gesamt_Ausland
# 0           50.000005         517.78383             584.915950
# ...

# %%
ausland_tages.describe()
# Out:
#        Umsatz_A_Ausland  Umsatz_B_Ausland  Umsatz_C_Ausland  \
# count        365.000000        365.000000        365.000000
# mean          53.052614         50.394521        496.254743
# std           39.525230         29.375140        282.785513
# min            0.269320          0.000000          1.025900
# 25%           20.319721         26.000000        235.650810
# 50%           47.325915         50.000005        517.783830
# 75%           78.839589         77.000000        733.315880
# max          171.461856        100.000000        993.935700
#
#        Umsatz_gesamt_Ausland
# count             365.000000
# mean              599.701877
# std               287.766058
# min                53.944434
# 25%               349.054438
# 50%               619.504486
# 75%               838.471316
# max              1149.038282

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(ausland_tages,palette="pastel")
plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Box_Aus")

# %%
filepaths = [r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_Produkt_Inland.png",
r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_Produkt_Ausland.png"]
#r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Line_Pro_Mo_Inland.png",
#r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Line_Pro_Mo_Ausland.png",

r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Heat_Inland.png",r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Heat_Ausland.png"

# Anzahl der Zeilen und Spalten im Raster
num_rows = 1
num_cols = 2

# Größe des Gesamtrasters
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10,8))

# Schleife zum Laden und Anzeigen der gespeicherten Bilder
for i, ax in enumerate(axes.flat):
    if i < len(filepaths):
        img = mpimg.imread(filepaths[i])
        ax.imshow(img)
        ax.axis('off')
    else:
        ax.axis('off')
plt.tight_layout()
plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_Vergleich")

# %%
df_in = pd.read_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_Inland.csv")
df_in
# Out:
#    Monat  Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# 0    Jan         15562.55         14774.46        148945.17
# 1    Feb         14055.57         15176.47        128859.95
# 2    Mrz         15633.91         18280.33        141602.71
# 3    Apr         15792.85         19095.32        133780.49
# 4    Mai         16947.49         20206.11        135993.78
# 5    Jun         17082.75         20056.65        135206.77
# 6    Jul         17965.03         22288.14        143531.78
# 7    Aug         17720.17         21707.81        139714.63
# 8    Sep         16870.28         21084.84        130178.03
# 9    Okt         17579.24         21564.91        128966.72
# 10   Nov         17567.79         20566.41        122411.82
# 11   Dez         18653.34         22364.24        126539.08
#
#     Umsatz_gesamt_Inland
# 0              179282.18
# 1              158091.99
# 2              175516.95
# 3              168668.66
# 4              173147.38
# 5              172346.17
# ...

# %%
df_in.describe()
# Out:
#        Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  Umsatz_gesamt_Inland
# count        12.000000        12.000000        12.000000             12.000000
# mean      16785.914167     19763.807500    134644.244167         171193.965833
# std        1292.536200      2547.960689      7754.663591           7594.773240
# min       14055.570000     14774.460000    122411.820000         158091.990000
# 25%       15753.115000     18891.572500    128940.027500         167972.317500
# 50%       17015.120000     20386.260000    134493.630000         170507.415000
# 75%       17614.472500     21600.635000    140186.650000         176423.365000
# max       18653.340000     22364.240000    148945.170000         183784.950000

# %%
#box_in = df_in.drop("Umsatz_gesamt_Inland", axis=1)
plt.figure(figsize=(10, 6))
sns.boxplot(df_in,palette="pastel")
plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Box_In")

# %%
r2 = df_in[df_in["Umsatz_gesamt_Inland"]== df_in["Umsatz_gesamt_Inland"].max()]
print(r2)
# Out:
#   Monat  Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# 6   Jul         17965.03         22288.14        143531.78
#
#    Umsatz_gesamt_Inland
# 6             183784.95

# %%
r2 = df_in[df_in["Umsatz_gesamt_Inland"]== df_in["Umsatz_gesamt_Inland"].min()]
print(r2)
# Out:
#   Monat  Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# 1   Feb         14055.57         15176.47        128859.95
#
#    Umsatz_gesamt_Inland
# 1             158091.99

# %%
df = pd.read_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_gesamt.csv")
df
# Out:
#    Monat  Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 0    Jan          15494.83           1897.14            1478.0
# 1    Feb          13204.74           1450.65            1349.0
# 2    Mrz          15034.96           1752.35            1369.0
# 3    Apr          14714.37           1423.80            1375.0
# 4    Mai          14771.97           1434.76            1470.0
# 5    Jun          16086.88           1662.89            1462.0
# 6    Jul          15029.18           2157.21            1781.0
# 7    Aug          14349.50           1725.48            1745.0
# 8    Sep          16560.05           1210.21            1515.0
# 9    Okt          15671.86           1522.83            1547.0
# 10   Nov          16808.34           1529.05            1581.0
# 11   Dez          13406.31           1597.83            1722.0
#
#     Umsatz_gesamt_Ausland  Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# ...

# %%
df.sum()
# Out:
# Monat                    JanFebMrzAprMaiJunJulAugSepOktNovDez
# Umsatz_C_Ausland                                    181132.99
# Umsatz_A_Ausland                                      19364.2
# Umsatz_B_Ausland                                      18394.0
# Umsatz_gesamt_Ausland                               218891.18
# Umsatz_A_Inland                                     201430.97
# Umsatz_B_Inland                                     237165.69
# Umsatz_C_Inland                                    1615730.93
# Umsatz_gesamt_Inland                               2054327.59
# dtype: object

# %%
df = df.drop(["Umsatz_C_Ausland","Umsatz_A_Ausland","Umsatz_B_Ausland","Umsatz_A_Inland","Umsatz_B_Inland","Umsatz_C_Inland"],axis=1)
df
# Out:
#    Monat  Umsatz_gesamt_Ausland  Umsatz_gesamt_Inland
# 0    Jan               18869.97             179282.18
# 1    Feb               16004.40             158091.99
# 2    Mrz               18156.30             175516.95
# 3    Apr               17513.17             168668.66
# 4    Mai               17676.73             173147.38
# 5    Jun               19211.77             172346.17
# 6    Jul               18967.38             183784.95
# 7    Aug               17819.99             179142.61
# 8    Sep               19285.26             168133.15
# 9    Okt               18741.68             168110.87
# 10   Nov               19918.39             160546.02
# 11   Dez               16726.14             167556.66

# %%
#df= df.set_index("Monat")
df.describe()
# Out:
#        Umsatz_gesamt_Ausland  Umsatz_gesamt_Inland
# count              12.000000             12.000000
# mean            18240.931667         171193.965833
# std              1142.173492           7594.773240
# min             16004.400000         158091.990000
# 25%             17635.840000         167972.317500
# 50%             18448.990000         170507.415000
# 75%             19028.477500         176423.365000
# max             19918.390000         183784.950000

# %%
df.sum()
# Out:
# Monat                    JanFebMrzAprMaiJunJulAugSepOktNovDez
# Umsatz_gesamt_Ausland                               218891.18
# Umsatz_gesamt_Inland                               2054327.59
# dtype: object

# %%
sns.barplot(df, palette="pastel",errwidth=0,estimator="sum")
#plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Line_Gesamtumsatz")

# %%
#plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Line_Gesamtumsatz")

# %%
plt.pie(df_in.sum(),autopct='%.0f%%',colors=colors)
plt.title("Umsatzverteilung Inland/Ausland")

#plt.savefig(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Diagrame\Pie_Gesamtumsatz")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plt.pie(df_in.sum(),autopct='%.0f%%',colors=colors)
#       2 plt.title("Umsatzverteilung Inland/Ausland")
#
# File c:\ProgramData\Miniconda3\envs\Playground\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
# ...
