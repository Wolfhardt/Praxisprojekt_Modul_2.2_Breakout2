# %%
import pandas as pd

# %%
dfx = pd.read_excel(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_Inland.xlsx")
dfx
# Out:
#     Unnamed: 0 Datum  Produkt_A_Inland  Produkt_B_Inland  Produkt_C_Inland
# 0            0   Jan          15562.55          14774.46         148945.17
# 1            1   Feb          14055.57          15176.47         128859.95
# 2            2   Mrz          15633.91          18280.33         141602.71
# 3            3   Apr          15792.85          19095.32         133780.49
# 4            4   Mai          16947.49          20206.11         135993.78
# 5            5   Jun          17082.75          20056.65         135206.77
# 6            6   Jul          17965.03          22288.14         143531.78
# 7            7   Aug          17720.17          21707.81         139714.63
# 8            8   Sep          16870.28          21084.84         130178.03
# 9            9   Okt          17579.24          21564.91         128966.72
# 10          10   Nov          17567.79          20566.41         122411.82
# ...

# %%
df = pd.read_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_Inland.csv")
df
# Out:
#    Monat  Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# 0    Jan         15562.55         14774.46        148945.17
# 1    Feb         14055.57         15176.47        128859.95
# 2    Mrz         15633.91         18280.33        141602.71
# 3    Apr         15792.85         19095.32        133780.49
# 4    Mai         16947.49         20206.11        135993.78
# 5    Jun         17082.75         20056.65        135206.77
# 6    Jul         17965.03         22288.14        143531.78
# 7    Aug         17720.17         21707.81        139714.63
# 8    Sep         16870.28         21084.84        130178.03
# 9    Okt         17579.24         21564.91        128966.72
# 10   Nov         17567.79         20566.41        122411.82
# 11   Dez         18653.34         22364.24        126539.08
#
#     Umsatz_gesamt_Inland
# 0              179282.18
# 1              158091.99
# 2              175516.95
# 3              168668.66
# 4              173147.38
# 5              172346.17
# ...

# %%
df1 = pd.read_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_Ausland_Monat.csv", usecols=["Umsatz_C_Ausland", "Umsatz_A_Ausland", "Umsatz_B_Ausland", "Umsatz_gesamt_Ausland"])
df1
# Out:
#     Umsatz_C_Ausland  Umsatz_A_Ausland  Umsatz_B_Ausland  \
# 0           15316.70           1897.12           1617.47
# 1           13714.71           1450.64           1349.00
# 2           14833.53           1752.35           1369.00
# 3           14823.54           1423.79           1375.00
# 4           14960.25           1434.76           1470.00
# 5           15732.23           1662.91           1462.00
# 6           14612.62           2157.20           1781.00
# 7           14591.92           1725.46           1745.00
# 8           16882.66           1210.21           1515.00
# 9           15624.29           1522.84           1547.00
# 10          16581.58           1529.06           1581.00
# 11          13484.32           1597.82           1722.00
#
#     Umsatz_gesamt_Ausland
# 0                18831.29
# 1                16514.35
# 2                17954.88
# 3                17622.33
# 4                17865.01
# 5                18857.14
# 6                18550.82
# ...

# %%
df_ges= pd.merge(df,df1,left_index=True, right_index=True)
df_ges = df_ges.set_index("Monat")
df_ges
# Out:
#        Umsatz_A_Inland  Umsatz_B_Inland  Umsatz_C_Inland  \
# Monat
# Jan           15562.55         14774.46        148945.17
# Feb           14055.57         15176.47        128859.95
# Mrz           15633.91         18280.33        141602.71
# Apr           15792.85         19095.32        133780.49
# Mai           16947.49         20206.11        135993.78
# Jun           17082.75         20056.65        135206.77
# Jul           17965.03         22288.14        143531.78
# Aug           17720.17         21707.81        139714.63
# Sep           16870.28         21084.84        130178.03
# Okt           17579.24         21564.91        128966.72
# Nov           17567.79         20566.41        122411.82
# Dez           18653.34         22364.24        126539.08
#
#        Umsatz_gesamt_Inland  Umsatz_C_Ausland  Umsatz_A_Ausland  \
# Monat
# Jan               179282.18          15316.70           1897.12
# Feb               158091.99          13714.71           1450.64
# ...

# %%
df_ges.to_csv(r"C:\Users\User\Documents\GitHub\Praxisprojekt_Modul_2.2_Breakout2\Daten\Umsatz_gesamt.csv")
